# %% [markdown]
# # 安装所需工具包

# %% [markdown]
# 同济大学张子豪 https://space.bilibili.com/1900783

# %%
# !pip3 install mediapipe==0.10.5 opencv-python numpy --upgrade -i http://mirrors.aliyun.com/pypi/simple/ --trusted-host mirrors.aliyun.com
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
import mediapipe
import cv2
import numpy

# %% [markdown]
# 能正常导入即可运行后面的代码
